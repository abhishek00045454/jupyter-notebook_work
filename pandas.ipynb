# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 389F-0762
#
#  Directory of C:\Users\Yaksha\Desktop\abhi.cpp\Untitled Folder
#
# 13-01-2023  19:35    <DIR>          .
# 13-01-2023  19:35    <DIR>          ..
# 13-01-2023  18:51    <DIR>          .ipynb_checkpoints
# 06-12-2022  00:16    <DIR>          __pycache__
# 08-01-2023  00:00         4,407,102 19.3 MongoDB.7z
# 10-01-2023  12:33             8,192 abhisheksaini_44
# 13-01-2023  01:24            73,216 alcohol.xls
# 12-01-2023  23:43               180 Book1.csv
# 13-01-2023  01:19             9,199 Book2.xlsx
# 12-01-2023  18:50            14,784 country_wise_latest.csv
# 12-01-2023  18:50         3,305,202 covid_19_clean_complete.csv
# 12-01-2023  18:50            14,432 day_wise.csv
# 29-12-2022  19:12           879,767 gamer.txt
# 25-12-2022  17:23            11,903 glass.data
# 13-01-2023  01:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# ...

# %%
pd.read_csv("BOOK1.CSV")
# Out:
#             name                      email  pincode sername
# 0  Abhisheksaini  abhisheksaini388gmail.com   332001   saini
# 1    Amit  saini      amitsaini374gmail.com   332210   saini
# 2   kartik saini    kartiksaini322gmail.com    78752   saini

# %%
pd.read_csv("glass.data")
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
pd.read_csv(r"C:\Users\Yaksha\Desktop\abhi.cpp\employees.csv")
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %%
pd.read_csv("country_wise_latest.csv")
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 389F-0762
#
#  Directory of C:\Users\Yaksha\Desktop\abhi.cpp\Untitled Folder
#
# 13-01-2023  01:46    <DIR>          .
# 13-01-2023  01:46    <DIR>          ..
# 12-01-2023  18:46    <DIR>          .ipynb_checkpoints
# 06-12-2022  00:16    <DIR>          __pycache__
# 08-01-2023  00:00         4,407,102 19.3 MongoDB.7z
# 10-01-2023  12:33             8,192 abhisheksaini_44
# 13-01-2023  01:24            73,216 alcohol.xls
# 12-01-2023  23:43               180 Book1.csv
# 13-01-2023  01:19             9,199 Book2.xlsx
# 12-01-2023  18:50            14,784 country_wise_latest.csv
# 12-01-2023  18:50         3,305,202 covid_19_clean_complete.csv
# 12-01-2023  18:50            14,432 day_wise.csv
# 29-12-2022  19:12           879,767 gamer.txt
# 25-12-2022  17:23            11,903 glass.data
# 13-01-2023  01:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# ...

# %%
pd.read_csv("covid_19_clean_complete.csv",header=None)
# Out:
#                     0                      1                   2          3  \
# 0      Province/State         Country/Region                 Lat       Long
# 1                 NaN            Afghanistan            33.93911  67.709953
# 2                 NaN                Albania             41.1533    20.1683
# 3                 NaN                Algeria             28.0339     1.6596
# 4                 NaN                Andorra             42.5063     1.5218
# ...               ...                    ...                 ...        ...
# 49064             NaN  Sao Tome and Principe              0.1864     6.6131
# 49065             NaN                  Yemen  15.552726999999999  48.516388
# 49066             NaN                Comoros            -11.6455    43.3333
# 49067             NaN             Tajikistan              38.861    71.2761
# 49068             NaN                Lesotho              -29.61    28.2336
#
# ...

# %%
type(cv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 type(cv)
#
# NameError: name 'cv' is not defined

# %%
pd.read_csv("Book1.csv",sep="@")
# Out:
#                           name|email|pincode|sername
# 0  Abhisheksaini|abhisheksaini388|gmail.com|33200...
# 1    Amit  saini|amitsaini374|gmail.com|332210|saini
# 2  kartik saini|kartiksaini322|gmail.com|78752|saini

# %%
pd.read_csv("Book1.csv",sep="|")
# Out:
#                           name,email,pincode,sername
# 0  Abhisheksaini,abhisheksaini388,gmail.com,33200...
# 1    Amit  saini,amitsaini374,gmail.com,332210,saini
# 2  kartik saini,kartiksaini322,gmail.com,78752,saini

# %%
pd.read_csv("Book1.csv",sep="@",skiprows=[0,2])
# Out:
#   Abhisheksaini,abhisheksaini388gmail.com,332001,saini
# 0   kartik saini,kartiksaini322gmail.com,78752,saini

# %%
df=pd.read_csv("day_wise.csv")

# %%
df.dtypes
# Out:
# Date                       object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# No. of countries            int64
# dtype: object

# %%
df.head(3)
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# 2                   72.22                 9

# %%
df.tail(2)
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 186         134721                3.99                  57.18
# 187         174623                3.97                  57.45
#
#      Deaths / 100 Recovered  No. of countries
# 186                    6.98               187
# 187                    6.91               187

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                       object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# No. of countries            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
a=df['Date']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df1=df[['Date','Deaths','No. of countries']]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2=df[["Date"]]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("day_wise.csv")
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 389F-0762
#
#  Directory of C:\Users\Yaksha\Desktop\abhi.cpp\Untitled Folder
#
# 13-01-2023  01:24    <DIR>          .
# 13-01-2023  01:24    <DIR>          ..
# 12-01-2023  18:46    <DIR>          .ipynb_checkpoints
# 06-12-2022  00:16    <DIR>          __pycache__
# 08-01-2023  00:00         4,407,102 19.3 MongoDB.7z
# 10-01-2023  12:33             8,192 abhisheksaini_44
# 13-01-2023  01:24            73,216 alcohol.xls
# 12-01-2023  23:43               180 Book1.csv
# 13-01-2023  01:19             9,199 Book2.xlsx
# 12-01-2023  18:50            14,784 country_wise_latest.csv
# 12-01-2023  18:50         3,305,202 covid_19_clean_complete.csv
# 12-01-2023  18:50            14,432 day_wise.csv
# 29-12-2022  19:12           879,767 gamer.txt
# 25-12-2022  17:23            11,903 glass.data
# 10-01-2023  00:07             3,066 mongo1.ipynb
# 09-01-2023  23:47            14,670 mongodb2.ipynb
# ...

# %%
pd.read_excel("Book2.xlsx")
# Out:
#    sno      name                       emial sirname
# 0    1  abhsiehk  abhisheksaini388@gmail.com   saini
# 1    2     ankit      ankitsaini88@gmail.com   saini
# 2    3     nitin     nitinswami877@gmail.com   saini
# 3    4     ayush     ayushbubna777@gmail.com   saini
# 4    5    hitesh    hiteshmeena741@gmail.com   saini
# 5    6    govind         gobbin877@gmail.com   saini

# %%
pd.read_excel("alcohol.xls")
# Out:
#      A  K     X  Y
# 0    2  2   758  1
# 1    2  3  1785  1
# 2    3  0  1200  1
# 3    1  0   545  1
# 4    4  1   547  1
# ..  .. ..   ... ..
# 995  2  3   704  1
# 996  2  0   822  1
# 997  2  0  1383  1
# 998  2  2   816  0
# 999  2  2   387  0
#
# [1000 rows x 4 columns]

# %%
pd_1=pd.read_excel("LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx",sheet_name="Introduction")

# %%
pd_1.keys
# Out:
# <bound method NDFrame.keys of     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
PD_1=pd.ExcelFile("LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx")

# %%
PD_1.sheet_names
# Out:
# ['Introduction',
#  'Create scope and portfolio',
#  'Create your instrument universe',
#  'Set up initial holdings',
#  'Upserting market quotes',
#  'Run valuation',
#  'Securitising base fund',
#  'Unit price calc',
#  'Create foreign ccy portfolios',
#  'Add FX quotes',
#  'Set up foreign holdings',
#  'Valuing foreign holdings',
#  'Additional transaction',
#  'Re-valuing base fund',
#  'Re-valuing (2)',
#  'Inputs']

# %%
PD_2=pd.ExcelFile("LUSID Excel - Manage your investment strategies.xlsx")

# %%
PD_2.sheet_names
# Out:
# ['Introduction',
#  'Create scope, portfolio, group',
#  'Create your instrument universe',
#  'Set up initial holdings',
#  'Add property definition',
#  'Add transactions',
#  'Upserting market quotes',
#  'Run valuation',
#  'Aggregate by strategy',
#  'Inputs']

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
