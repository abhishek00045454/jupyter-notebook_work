# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",index=False)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df_1=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2020.html")

# %%
type(df_1)
# Out:
# list

# %%
type(df_1[0])
# Out:
# pandas.core.frame.DataFrame

# %%
col=df_1[0]

# %%
col.columns
# Out:
# Index(['Eastern Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS'], dtype='object')

# %%
col.head()
# Out:
#   Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0   Milwaukee Bucks*  56  17  0.767     —  118.7  108.6  9.41
# 1   Toronto Raptors*  53  19  0.736   2.5  112.8  106.5  5.97
# 2    Boston Celtics*  48  24  0.667   7.5  113.7  107.3  5.83
# 3    Indiana Pacers*  45  28  0.616  11.0  109.4  107.5  1.63
# 4        Miami Heat*  44  29  0.603  12.0  112.0  109.1  2.59

# %%
col.tail(3)
# Out:
#      Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 12      Detroit Pistons  20  46  0.303  32.5  107.2  110.8 -4.38
# 13        Atlanta Hawks  20  47  0.299  33.0  111.8  119.7 -7.71
# 14  Cleveland Cavaliers  19  46  0.292  33.0  106.9  114.8 -7.77

# %%
col.dtypes
# Out:
# Milwaukee Bucks*     object
# 56                    int64
# 17                    int64
# .767                float64
# —                   float64
# 118.7               float64
# 108.6               float64
# 9.41                float64
# dtype: object

# %%
col[["W","L"]]
# Out:
#      W   L
# 0   56  17
# 1   53  19
# 2   48  24
# 3   45  28
# 4   44  29
# 5   43  30
# 6   35  37
# 7   33  40
# 8   23  42
# 9   25  47
# 10  22  43
# 11  21  45
# 12  20  46
# 13  20  47
# 14  19  46

# %%
fr_1=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
fr_1.to_csv("titanic.csv",index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 389F-0762
#
#  Directory of C:\Users\Yaksha\Desktop\abhi.cpp\Untitled Folder
#
# 14-01-2023  00:22    <DIR>          .
# 14-01-2023  00:22    <DIR>          ..
# 13-01-2023  18:51    <DIR>          .ipynb_checkpoints
# 06-12-2022  00:16    <DIR>          __pycache__
# 08-01-2023  00:00         4,407,102 19.3 MongoDB.7z
# 10-01-2023  12:33             8,192 abhisheksaini_44
# 13-01-2023  01:24            73,216 alcohol.xls
# 12-01-2023  23:43               180 Book1.csv
# 13-01-2023  01:19             9,199 Book2.xlsx
# 12-01-2023  18:50            14,784 country_wise_latest.csv
# 12-01-2023  18:50         3,305,202 covid_19_clean_complete.csv
# 12-01-2023  18:50            14,432 day_wise.csv
# 29-12-2022  19:12           879,767 gamer.txt
# 25-12-2022  17:23            11,903 glass.data
# 13-01-2023  01:30           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# ...

# %%
fr_1.to_csv("titanic.csv",index=False,header=False)

# %%
pd.read_csv("ODI data.csv")
# Out:
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1    -   -      -
# 2496          46         Ariful Haque (BDESH)  2018-2018    1    -   -      -
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -
# 2498          48               MD Bailey (NZ)  1998-1998    1    -   -      -
# 2499          49               GR Beard (AUS)  1981-1981    2    -   -      -
#
# ...

# %%
fr_2=pd.read_html("https://www.espn.in/football/stats/_/league/fifa.world")

# %%
len(fr_2)
# Out:
# 2

# %%
fr_2[0]
# Out:
#       RK                    Name          Team  P  G
# 0    1.0           Kylian Mbappé        France  7  8
# 1    2.0            Lionel Messi     Argentina  7  7
# 2    3.0          Julián Álvarez     Argentina  7  4
# 3    NaN          Olivier Giroud        France  6  4
# 4    5.0              Cody Gakpo   Netherlands  5  3
# 5    NaN         Marcus Rashford       England  5  3
# 6    NaN             Richarlison        Brazil  4  3
# 7    NaN             Bukayo Saka       England  4  3
# 8    NaN           Álvaro Morata         Spain  4  3
# 9    NaN           Goncalo Ramos      Portugal  4  3
# 10   NaN          Enner Valencia       Ecuador  3  3
# 11  12.0       Youssef En-Nesyri       Morocco  7  2
# 12   NaN         Andrej Kramaric       Croatia  7  2
# 13   NaN              Harry Kane       England  5  2
# 14   NaN             Rafael Leão      Portugal  5  2
# 15   NaN      Robert Lewandowski        Poland  4  2
# 16   NaN         Bruno Fernandes      Portugal  4  2
# ...
